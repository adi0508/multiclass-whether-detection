# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy88.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy167.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy78.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy80.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy2.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy89.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy99.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy256.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy9.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy185.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy208.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy44.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy269.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy102.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy20.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy30.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy71.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy67.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy72.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy150.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy242.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy116.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy300.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy162.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy113.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy218.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy165.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy129.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy220.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy124.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy160.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy40.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy168.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy154.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy58.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy43.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy106.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy13.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy115.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy267.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy31.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy52.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy1.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy288.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy273.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy143.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy53.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy221.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy137.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy247.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy234.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy29.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy24.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy209.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy39.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy240.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy27.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy258.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy51.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy112.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy28.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy110.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy117.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy158.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy45.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy76.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy107.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy96.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy119.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy195.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy285.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy108.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy236.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy120.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy184.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy21.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy235.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy93.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy139.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy271.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy111.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy86.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy190.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy54.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy174.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy90.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy127.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy251.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy277.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy65.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy131.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy181.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy103.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy183.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy178.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy12.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy237.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy156.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy294.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy290.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy7.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy109.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy282.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy130.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy56.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy22.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy210.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy172.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy188.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy123.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy243.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy228.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy212.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy182.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy114.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy248.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy14.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy25.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy60.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy128.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy200.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy18.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy276.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy145.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy284.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy35.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy75.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy293.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy272.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy255.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy214.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy170.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy92.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy46.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy297.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy291.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy136.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy263.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy245.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy193.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy270.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy85.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy69.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy125.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy217.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy211.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy254.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy63.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy141.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy202.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy153.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy104.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy74.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy84.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy169.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy203.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy207.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy250.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy283.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy238.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy180.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy82.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy49.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy280.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy265.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy135.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy292.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy11.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy186.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy231.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy15.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy59.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy121.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy47.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy197.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy215.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy161.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy159.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy296.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy275.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy81.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy34.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy253.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy142.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy173.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy70.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy298.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy192.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy38.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy179.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy205.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy219.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy23.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy126.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy144.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy8.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy171.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy187.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy148.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy32.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy16.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy95.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy33.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy252.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy87.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy164.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy50.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy68.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy239.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy232.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy289.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy17.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy230.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy105.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy166.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy149.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy41.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy79.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy233.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy201.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy151.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy194.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy147.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy206.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy299.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy152.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy73.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy266.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy4.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy176.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy279.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy91.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy36.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy163.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy278.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy64.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy42.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy66.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy177.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy259.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy274.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy229.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy133.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy224.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy62.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy196.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy213.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy204.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy122.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy5.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy261.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy77.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy249.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy98.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy225.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy216.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy189.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy295.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy97.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy26.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy241.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy175.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy3.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy286.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy19.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy138.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy37.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy94.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy83.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy226.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy199.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy157.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy10.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy146.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy268.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy262.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy155.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy246.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy257.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy6.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy100.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy191.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy264.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy132.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy222.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy101.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy198.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy281.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy244.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy57.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy55.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy223.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy287.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy134.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy260.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy227.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy118.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy140.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy48.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy61.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise194.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise120.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise22.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise87.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise80.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise277.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise347.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise191.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise36.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise260.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise225.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise84.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise34.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise275.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise168.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise316.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise283.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise179.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise174.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise25.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise224.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise223.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise52.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise247.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise207.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise238.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise144.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise43.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise353.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise95.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise218.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise348.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise354.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise242.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise292.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise2.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise355.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise268.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise343.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise159.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise92.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise135.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise352.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise3.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise357.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise56.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise39.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise133.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise114.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise234.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise49.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise96.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise315.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise334.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise157.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise47.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise9.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise134.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise249.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise209.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise38.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise339.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise346.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise287.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise27.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise97.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise16.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise177.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise57.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise244.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise170.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise258.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise210.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise85.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise115.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise156.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise255.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise231.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise181.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise193.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise311.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise349.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise253.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise66.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise217.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise103.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise297.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise26.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise265.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise326.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise93.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise41.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise178.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise100.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise304.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise284.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise5.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise46.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise171.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise278.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise81.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise333.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise280.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise172.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise330.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise59.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise123.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise229.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise317.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise214.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise299.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise263.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise140.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise58.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise32.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise199.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise310.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise190.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise15.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise246.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise213.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise74.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise226.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise152.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise131.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise116.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise266.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise44.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise243.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise276.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise98.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise288.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise165.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise31.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise282.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise303.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise302.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise79.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise119.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise63.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise272.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise124.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise28.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise338.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise132.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise155.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise65.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise150.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise192.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise163.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise182.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise227.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise166.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise75.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise176.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise252.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise91.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise320.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise294.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise322.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise24.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise305.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise328.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise237.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise197.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise102.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise33.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise216.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise40.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise17.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise45.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise274.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise88.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise69.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise149.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise118.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise128.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise323.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise101.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise125.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise290.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise271.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise99.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise175.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise68.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise164.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise309.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise319.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise211.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise106.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise4.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise291.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise121.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise77.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise314.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise14.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise29.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise344.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise60.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise233.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise206.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise293.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise70.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise151.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise202.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise142.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise324.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise67.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise126.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise37.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise327.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise196.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise188.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise153.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise251.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise158.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise264.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise200.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise186.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise19.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise350.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise201.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise331.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise230.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise239.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise329.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise113.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise325.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise295.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise139.jpg
# ...
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine140.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine74.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine142.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine122.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine209.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine39.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine141.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine41.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine182.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine211.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine187.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine194.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine37.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine111.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine82.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine52.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine108.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine34.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine27.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine56.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine109.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine129.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine29.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine234.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine80.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine116.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine36.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine219.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine42.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine159.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine250.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine192.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine213.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine45.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine133.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine31.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine76.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine178.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine64.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine158.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine17.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine156.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine120.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine161.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine170.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine168.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine38.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine202.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine94.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine228.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine55.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine242.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine185.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine190.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine232.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine180.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine200.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine119.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine144.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine166.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine131.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine5.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine145.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine33.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine205.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine244.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine183.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine135.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine123.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine252.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine196.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine50.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine126.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine150.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine188.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine103.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine151.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine10.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine162.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine62.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine110.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine66.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine90.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine101.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine216.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine44.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine231.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine102.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine174.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine2.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine236.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine253.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine230.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine100.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine165.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine93.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine60.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine154.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine19.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine224.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine193.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine207.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine77.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine47.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine157.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine218.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine189.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine172.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine171.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine71.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine243.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine134.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine4.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine89.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine139.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine169.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine58.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine72.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine70.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine206.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine51.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine114.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine9.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine6.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine67.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine173.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine149.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine148.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine153.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine240.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine221.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine125.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine26.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine214.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine181.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine53.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine138.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine61.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine73.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine14.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine225.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine128.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine69.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine84.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine107.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine238.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine124.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine177.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine88.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine248.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine63.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine25.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine237.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine22.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine198.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine12.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine113.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine30.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine241.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine21.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine249.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine75.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine197.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine32.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine35.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine132.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine223.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine20.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine199.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine179.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine65.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine222.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine86.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine95.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine87.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine212.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine78.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine176.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine13.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine160.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine220.jpg
# /kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine8.jpg

# %% [markdown]
# # **And Here goes the Code**

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import os
import glob
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
from torchvision.datasets import ImageFolder

# %%
base_dir =  r'/kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset'
folders = os.listdir(base_dir)
print(folders)
# Out:
# ['Cloudy', 'Sunrise', 'Rain', 'Shine']

# %%
# labeling files with Image Data Generator

train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(250 , 250),
    batch_size= 32,
    class_mode='categorical',
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    base_dir, # same directory as training data
    target_size=(250, 250),
    batch_size= 32,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
# Generated Labels
labels = (train_generator.class_indices)
labels = dict((v , k) for k , v in labels.items())
print(labels)
# Out:
# {0: 'Cloudy', 1: 'Rain', 2: 'Shine', 3: 'Sunrise'}

# %%
# # setting seed and clearing session
# tf.keras.backend.clear_session()
# tf.random.set_seed(51)
# np.random.seed(51)

# %%
num_classes = 4

# defining model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5,5), input_shape = (250 , 250 , 3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(3,3),
    tf.keras.layers.Conv2D(64, (5,5) , activation = 'relu'),
    tf.keras.layers.MaxPool2D((3,3)),
    tf.keras.layers.Conv2D(128 , (5,5) , activation = 'relu'),
    tf.keras.layers.MaxPool2D(3,3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5, seed = 5),
    tf.keras.layers.Dense(128 , activation = 'relu'),
    tf.keras.layers.Dense(num_classes , activation = 'softmax')])

# %%
# getting model summary after compiling
model.compile(loss = 'categorical_crossentropy' , optimizer = tf.keras.optimizers.Adam(lr = 0.001) , metrics = 'accuracy')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 246, 246, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 82, 82, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 78, 78, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 128)       204928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               802944
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 1,062,084
# Trainable params: 1,062,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
# defining callback for early stopping
class My_callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self , epochs , logs = {}):
        if(logs.get('accuracy') > 0.85 and logs.get('val_accuracy') > 0.85):
            print('\n stopping training')
            self.model.stop_training = True
            
callbacks = My_callback()

# %%
# training model
history = model.fit(train_generator ,
          validation_data = validation_generator ,
          epochs = 15 ,
          steps_per_epoch = 901/32, # train_files/batch_size
          validation_steps = 224/32,), # valid_files/batch_size 
callbacks = [callbacks]
# Out:
#   File "<ipython-input-22-6049e486e927>", line 7
#     callbacks = [callbacks]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **Clearly As Can Be Seen loss < val_loss , maybe model overfits**

# %%
# displaying graphs

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.title(string)
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
def prediction(test_path):
    img = image.load_img(test_path , target_size = (250 , 250))
    img = image.img_to_array(img, dtype=np.uint8)
    img = np.array(img)/255.0
        
    plt.title('Image')
    plt.axis('off')
    plt.imshow(img.squeeze())
        
    predict = model.predict(img[np.newaxis , ...])
    predicted_class = labels[np.argmax(predict[0] , axis = -1)]
        
    print('Prediction Value: ' , np.max(predict[0] , axis = -1))
    print("Classified:",predicted_class)

# %%
test_path = r'../input/multiclass-weather-dataset/Multi-class Weather Dataset/Cloudy/cloudy1.jpg'
prediction(test_path)
# Out:
# Prediction Value:  0.9798504
# Classified: Cloudy

# %%
test_path = r'../input/multiclass-weather-dataset/Multi-class Weather Dataset/Rain/rain1.jpg'
prediction(test_path)
# Out:
# Prediction Value:  0.95922405
# Classified: Rain

# %%
test_path = r'../input/multiclass-weather-dataset/Multi-class Weather Dataset/Shine/shine11.jpg'
prediction(test_path)
# Out:
# Prediction Value:  0.8549779
# Classified: Shine

# %%
test_path = r'../input/multiclass-weather-dataset/Multi-class Weather Dataset/Sunrise/sunrise106.jpg'
prediction(test_path)
# Out:
# Prediction Value:  0.999816
# Classified: Sunrise

# %%
model.save('./model.h5')
